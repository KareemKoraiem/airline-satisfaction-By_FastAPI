# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
df.shape
# Out:
# (103904, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
df.describe(include='object').T
# Out:
#                  count unique                      top   freq
# Gender          103904      2                   Female  52727
# Customer Type   103904      2           Loyal Customer  84923
# Type of Travel  103904      2          Business travel  71655
# Class           103904      3                 Business  49665
# satisfaction    103904      2  neutral or dissatisfied  58879

# %%
df['satisfaction'].value_counts(normalize=True)*100
# Out:
# satisfaction
# neutral or dissatisfied    56.666731
# satisfied                  43.333269
# Name: proportion, dtype: float64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Data Visualization (EDA)

# %%
for col in df.select_dtypes(include=['object']).columns:
    print(col, df[col].unique())
    print('-'*30)
# Out:
# Gender ['Male' 'Female']
# ------------------------------
# Customer Type ['Loyal Customer' 'disloyal Customer']
# ------------------------------
# Type of Travel ['Personal Travel' 'Business travel']
# ------------------------------
# Class ['Eco Plus' 'Business' 'Eco']
# ------------------------------
# satisfaction ['neutral or dissatisfied' 'satisfied']
# ------------------------------

# %%
categorical = df.select_dtypes(include=['object']).columns
numerical = df.select_dtypes(include=['number']).columns

# %%
for col in categorical:
    plt.figure(figsize=(10,5), dpi=100)
    plt.title(col)
    sns.countplot(x=col, data=df,hue='satisfaction')
    plt.show()

# %%
for col in numerical:
    plt.figure(figsize=(10,5))
    plt.subplot(1,2,1)
    sns.histplot(x=col, data=df,kde=True)
    plt.title(col)
    plt.subplot(1,2,2)
    sns.boxplot(x=col, data=df)
    plt.title(col)
    plt.show()

# %%
corr_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df = df.drop(['Departure Delay in Minutes','id','Unnamed: 0'],axis=1) # unnecessary columns

# %%
#df.dropna(inplace=True)
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# # Outliers

# %%
cols=['Flight Distance','Arrival Delay in Minutes']
for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3-q1

  upper = q3 + 1.5*iqr
  lower = q1 - 1.5*iqr

  outliers = df[(df[col] < lower) | (df[col] > upper)]
  print(f'{col}: {len(outliers)} outliers : ({len(outliers)/len(df)*100:.2f}%)')

  # We don’t have to deal with outliers because they are suitable in this data.
# Out:
# Flight Distance: 2287 outliers : (2.21%)
# Arrival Delay in Minutes: 13954 outliers : (13.47%)

# %% [markdown]
# # Split Data

# %%
x = df.drop('satisfaction',axis=1)
y = df['satisfaction']

# %%
# simple way to encode target
y = y.map({'neutral or dissatisfied':0,'satisfied':1})

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((82875, 21), (20719, 21), (82875,), (20719,))

# %% [markdown]
# # Encoding

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103594 entries, 0 to 103903
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103594 non-null  object
#  1   Customer Type                      103594 non-null  object
#  2   Age                                103594 non-null  int64
#  3   Type of Travel                     103594 non-null  object
#  4   Class                              103594 non-null  object
#  5   Flight Distance                    103594 non-null  int64
#  6   Inflight wifi service              103594 non-null  int64
#  7   Departure/Arrival time convenient  103594 non-null  int64
#  8   Ease of Online booking             103594 non-null  int64
#  9   Gate location                      103594 non-null  int64
#  10  Food and drink                     103594 non-null  int64
# ...

# %%
categorical = x.select_dtypes(include=['object']).columns
numerical = x.select_dtypes(include=['number']).columns

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
transformer = ColumnTransformer([('encoder',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),categorical)],remainder='passthrough')

x_train = transformer.fit_transform(x_train)
x_test = transformer.transform(x_test)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # Baseline Training Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score

from sklearn.model_selection import cross_val_score

# %%
base_results = []

# %%
def evaluate_model(model,x_train,y_train,x_test,y_test):
    model.fit(x_train,y_train)
    cv = cross_val_score(model,x_train,y_train,cv=5,scoring='accuracy')
    y_pred = model.predict(x_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    base_results.append({
        'Model': model.__class__.__name__,
        'Train Score': model.score(x_train,y_train),
        'Test Score': model.score(x_test,y_test),
        'CV Mean': cv.mean(),
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score': f1
    })

    print("="*50)
    print(model.__class__.__name__)
    print("="*50)
    print("train score :", model.score(x_train,y_train))
    print("test score :", model.score(x_test,y_test))

    print("Cross Validation Mean :", cv.mean())
    print("Accuracy :", accuracy)
    print("Precision:", precision)
    print("Recall   :", recall)
    print("F1 Score :", f1)
    print(classification_report(y_test, y_pred))
    print("="*50)
    print()

# %%
base_lg = LogisticRegression(random_state=42)
base_knn = KNeighborsClassifier()
base_dt = DecisionTreeClassifier(random_state=42,max_depth=15,min_samples_leaf=4,min_samples_split=10)
base_rf = RandomForestClassifier(random_state=42,max_depth=15,n_estimators=300,min_samples_split =10,min_samples_leaf=4)
base_nb = GaussianNB()
base_svm = SVC(random_state=42)
base_ada = AdaBoostClassifier(random_state=42)

# %%
evaluate_model(base_lg,x_train,y_train,x_test,y_test)
evaluate_model(base_knn,x_train,y_train,x_test,y_test)
evaluate_model(base_dt,x_train,y_train,x_test,y_test)
evaluate_model(base_rf,x_train,y_train,x_test,y_test)
evaluate_model(base_nb,x_train,y_train,x_test,y_test)
evaluate_model(base_svm,x_train,y_train,x_test,y_test)
evaluate_model(base_ada,x_train,y_train,x_test,y_test)
# Out:
# ...
# LogisticRegression
# ...
# train score : 0.8761266968325792
# test score : 0.8728703122737583
# Cross Validation Mean : 0.8759577677224737
# Accuracy : 0.8728703122737583
# Precision: 0.872451343836886
# Recall   : 0.8308693733451015
# F1 Score : 0.8511528028933092
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89     11655
#            1       0.87      0.83      0.85      9064
#
#     accuracy                           0.87     20719
#    macro avg       0.87      0.87      0.87     20719
# weighted avg       0.87      0.87      0.87     20719
#
# ...
#
# ...
# KNeighborsClassifier
# ...
# train score : 0.9476923076923077
# test score : 0.9260582074424442
# Cross Validation Mean : 0.9249713423831072
# Accuracy : 0.9260582074424442
# Precision: 0.9534071755357573
# Recall   : 0.873676081200353
# F1 Score : 0.9118019573978123
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94     11655
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
NN_model = Sequential([
    Dense(128, activation='relu', input_shape=(x_train.shape[1],)),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
NN_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = NN_model.fit(x_train, y_train, epochs=25, batch_size=32, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/25
# 2072/2072 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9172 - loss: 0.2033 - val_accuracy: 0.9446 - val_loss: 0.1318
# Epoch 2/25
# 2072/2072 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9437 - loss: 0.1368 - val_accuracy: 0.9525 - val_loss: 0.1142
# Epoch 3/25
# 2072/2072 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9495 - loss: 0.1214 - val_accuracy: 0.9537 - val_loss: 0.1035
# Epoch 4/25
# 2072/2072 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9524 - loss: 0.1119 - val_accuracy: 0.9566 - val_loss: 0.1027
# Epoch 5/25
# 2072/2072 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9549 - loss: 0.1071 - val_accuracy: 0.9587 - val_loss: 0.0966
# Epoch 6/25
# 2072/2072 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9567 - loss: 0.1025 - val_accuracy: 0.9611 - val_loss: 0.0935
# Epoch 7/25
# 2072/2072 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9578 - loss: 0.0988 - val_accuracy: 0.9601 - val_loss: 0.0926
# Epoch 8/25
# ...

# %%
train_loss, train_acc = NN_model.evaluate(x_train, y_train, verbose=0)
test_loss, test_acc = NN_model.evaluate(x_test, y_test, verbose=0)
print("Train Accuracy:", train_acc)
print("Test Accuracy:", test_acc)
# Out:
# Train Accuracy: 0.9638733267784119
# Test Accuracy: 0.9619672894477844

# %%
y_pred = NN_model.predict(x_test)
y_pred = (y_pred > 0.5).astype(int)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 648/648 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Accuracy: 0.9619672764129543
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97     11655
#            1       0.97      0.94      0.96      9064
#
#     accuracy                           0.96     20719
#    macro avg       0.96      0.96      0.96     20719
# weighted avg       0.96      0.96      0.96     20719

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
base_results.append({
        'Model': 'Neural Network',
        'Train Score': train_acc,
        'Test Score': test_acc,
        'CV Mean': None,
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision': precision_score(y_test, y_pred),
        'Recall': recall_score(y_test, y_pred),
        'F1 Score': f1_score(y_test, y_pred)
    })

# %%
base_results_df = pd.DataFrame(base_results)
base_results_df.columns = ['Model','Train Score','Test Score','CV Mean','Accuracy','Precision','Recall','F1 Score']
for col in base_results_df.columns[1:]:
    base_results_df[col] = base_results_df[col].map(lambda x: f'{x*100:.2f}%' if pd.notna(x) else x)
base_results_df
# Out:
#                     Model Train Score Test Score CV Mean Accuracy Precision  \
# 0      LogisticRegression      87.61%     87.29%  87.60%   87.29%    87.25%
# 1    KNeighborsClassifier      94.77%     92.61%  92.50%   92.61%    95.34%
# 2  DecisionTreeClassifier      96.96%     95.45%  95.09%   95.45%    96.07%
# 3  RandomForestClassifier      96.90%     96.00%  95.84%   96.00%    96.69%
# 4              GaussianNB      84.95%     84.87%  84.94%   84.87%    83.65%
# 5                     SVC      95.76%     95.45%  95.26%   95.45%    96.00%
# 6      AdaBoostClassifier      91.05%     91.21%  91.27%   91.21%    90.22%
# 7          Neural Network      96.39%     96.20%     NaN   96.20%    97.30%
#
#    Recall F1 Score
# 0  83.09%   85.12%
# 1  87.37%   91.18%
# 2  93.42%   94.73%
# 3  94.09%   95.37%
# 4  81.31%   82.47%
# 5  93.49%   94.73%
# 6  89.62%   89.92%
# 7  93.91%   95.58%

# %%
best_model = base_rf
y_pred = best_model.predict(x_test)
print(best_model.__class__.__name__)
print('='*50)
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.show()
print(classification_report(y_test, y_pred))
# Out:
# RandomForestClassifier
# ...
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     11655
#            1       0.97      0.94      0.95      9064
#
#     accuracy                           0.96     20719
#    macro avg       0.96      0.96      0.96     20719
# weighted avg       0.96      0.96      0.96     20719

# %% [markdown]
# # Hyperparameter Tuning

# %%
# مش هعملها علشان زهقت من الوقت
# جربتها مع نفسي مزودتش كتير كدا كدا
#Best Parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 30}

"""
from sklearn.model_selection import RandomizedSearchCV
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2,4]
}
grid_rf = RandomizedSearchCV(base_rf, param_grid_rf, cv=5, scoring='accuracy',n_jobs= -1)
grid_rf.fit(x_train, y_train)
print("Best Parameters:", grid_rf.best_params_)
print("Best Score:", grid_rf.best_score_)

"""
# Out:
# '\nfrom sklearn.model_selection import RandomizedSearchCV\nparam_grid_rf = {\n    \'n_estimators\': [100, 200, 300],\n    \'max_depth\': [None, 10, 20, 30],\n    \'min_samples_split\': [2, 5, 10],\n    \'min_samples_leaf\': [1, 2,4]\n}\ngrid_rf = RandomizedSearchCV(base_rf, param_grid_rf, cv=5, scoring=\'accuracy\',n_jobs= -1)\ngrid_rf.fit(x_train, y_train)\nprint("Best Parameters:", grid_rf.best_params_)\nprint("Best Score:", grid_rf.best_score_)\n\n'

# %%
"""
best_rf = grid_rf.best_estimator_
y_pred = best_rf.predict(x_test)
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.show()
print(classification_report(y_test, y_pred))

"""
# Out:
# "\nbest_rf = grid_rf.best_estimator_\ny_pred = best_rf.predict(x_test)\nsns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d')\nplt.title('Confusion Matrix')\nplt.show()\nprint(classification_report(y_test, y_pred))\n\n"

# %% [markdown]
# # Feature Importance

# %%
 feature_names = transformer.get_feature_names_out()
 feature_importances = best_model.feature_importances_

 feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
 feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

 feature_importance_df.head(10)
# Out:
#                                     Feature  Importance
# 16               remainder__Online boarding    0.180899
# 11         remainder__Inflight wifi service    0.150210
# 6                   encoder__Class_Business    0.083679
# 5   encoder__Type of Travel_Personal Travel    0.068209
# 4   encoder__Type of Travel_Business travel    0.063863
# 18        remainder__Inflight entertainment    0.055304
# 17                  remainder__Seat comfort    0.047269
# 7                        encoder__Class_Eco    0.045357
# 13        remainder__Ease of Online booking    0.035664
# 2     encoder__Customer Type_Loyal Customer    0.031155

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df.head(10))
plt.title('Top 10 Feature Importances')
plt.show()

# %% [markdown]
# # AUC & ROC score

# %%
from sklearn.metrics import roc_curve, auc
y_prob = best_model.predict_proba(x_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
auc_score = auc(fpr, tpr)
print("AUC Score:", auc_score)
# Out:
# AUC Score: 0.9933898247005044

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Saving Model

# %%
import joblib
features = x.columns.tolist()
joblib.dump(best_model,"model.pkl")
joblib.dump(transformer,"transformer.pkl")
joblib.dump(scaler,"scaler.pkl")
joblib.dump(features,"features.pkl")
# Out:
# ['features.pkl']

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1
